# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
user_data = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-m-vinokurov/3_user_data.csv')
logs = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-m-vinokurov/3_logs.csv')
logs = logs.merge(user_data, on='client', how='inner')
df= logs.query("platform == 'computer'")
df = df.groupby('age',as_index=False).agg({'success':'count'})
df
plt.figure(figsize=(12, 8))
sns.countplot(df['age'])
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
